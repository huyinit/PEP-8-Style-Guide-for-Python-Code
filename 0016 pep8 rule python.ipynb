# %% [markdown]
# **Python Enhancement Proposal #8 (thường được viết tắt PEP-8), là tập hợp các chỉ dẫn về định dạng code, phong cách lập trình được chia sẻ chung giữa các lập trình viên Python. PEP-8 được đề xuất bởi các chuyên gia trong "hội đồng" sáng lập ngôn ngữ lập trình Python. Việc viết code theo đúng chuẩn chung PEP-8 sẽ giúp cho các lập trình viên cảm thấy thoải mái hơn khi đọc code của nhau, kiểu như là đọc code người khác mà như đang đọc code của mình vậy.**

# %%
https://gist.github.com/RichardBronosky/454964087739a449da04
https://github.com/aboSamoor/pep8/blob/master/pep8.py
https://realpython.com/python-pep8/#comments

# %%
import os  # STD nhập lib đầu tiên (STD lib), Nhập tuyệt đối được khuyến nghị
import sys  # theo thứ tự bảng chữ cái , mỗi cái trên 1 dòng

import Django  # Related third party imports.(third-party modules) vd:Django, Flask, Pyramid.
import Flask  # theo thứ tự bảng chữ cái

import inspect  # Local application/library specific imports cuối cùng (Nhập ứng dụng / thư viện cục bộ cụ thể.)
import keyword  #dont_import_two, modules_in_one_line
import tokenize

from fnmatch import fnmatch  # from để cuối cùng 
from mypkg import sibling  # nhập khẩu tương đối rõ ràng là một lựa chọn thay thế được chấp nhận cho nhập khẩu tuyệt đối

# %%
# Khi bạn muốn comment code, sau dấu # nên đặt ít nhất một khoảng trắng.
# Nguyên tắc 04 khoảng trắng:
# 1. Đặt khoảng trắng trước và sau (bao xung quanh) các toán tử nhị phân, logic và phép gán:
# =, +=, -=, ==, <, >, !=, <>, <=, >=, in, not in, is, is not, and, or, not
# Khi thực hiện gán dữ liệu mặc định cho tham số truyền vào function thì không đặt khoảng trắng bao quanh dấu =
# Với các toán tử số học +, -, *, /, // lựa chọn bao xung quanh các toán tử bằng khoảng trắng (ở cả hai bên) hoặc không có khoảng trắng nào.


def naming_convention():
    """Write docstrings for ALL public classes, funcs and methods.
    Functions use snake_case.
    """
    if x == 4:  # đặt 2 khoảng trống trước dấu #
        x, y = y, x  # ít nhất 1 khoảng trống sau dấu #
    c = (a + b) * (a - b)  # khoảng cách giữa các toán tử nên cải thiện khả năng đọc.
    dict['key'] = dict[0] = {'x': 2, 'cat': 'not a dog'}
"""
Okay: i = i + 1
Okay: submitted += 1
Okay: x = x * 2 - 1
Okay: hypot2 = x * x + y * y
Okay: c = (a + b) * (a - b)
Okay: foo(bar, key='word', *args, **kwargs)
Okay: alpha[:-i]
"""

# %%
    #Mỗi dòng nên có độ dài nhỏ hơn 79 ký tự.
    # Khi thực hiện gán dữ liệu mặc định cho tham số truyền vào function thì không đặt khoảng trắng bao quanh dấu =
    def __init__(self, width, height,
                 color='black', emphasis=None, highlight=0):
        if width == 0 and height == 0 and \  # Đừng mong đợi dòng trống trước dòng đầu tiên
           color == 'red' and emphasis == 'strong' or \
           highlight > 100:
            raise ValueError('sorry, you lose')
        if width == 0 and height == 0 and (color == 'red' or
                                           emphasis is None):
            raise ValueError("I don't think so -- values are %s, %s" %
                             (width, height))
        Blob.__init__(self, width, height,  # khoảng trắng xung quanh dấu phẩy bên trái thì không , phải thì có
                      color, emphasis, highlight)

    # dòng trống trong phương pháp để nâng cao khả năng đọc; không có quy tắc thiết lập
    short_foo_dict = {'loooooooooooooooooooong_element_name': 'cat',
                      'other_element': 'dog'}

    long_foo_dict_with_many_elements = {
        'foo': 'cat',
        'bar': 'dog'
    }

# %%
# Trong một file (module), phía trên và phía dưới (bao xung quanh) của phần định nghĩa function, class là 02 blank-line.
# Với các function được định nghĩa trong một class thì bao xung quanh của function là 01 blank-line.
# Dòng cuối cùng của một file/module là một dòng trống.
class NamingConvention(object):
    """First line of a docstring is short and next to the quotes.
    Class and exception names are CapWords.
    Closing quotes are on their own line
    """
    a = 2
    b = 4
    _internal_variable = 3
    class_ = 'foo'  # dấu gạch dưới ở cuối để tránh xung đột với nội trang
    __internal_var = 4

    # KHÔNG BAO GIỜ sử dụng dấu gạch dưới kép ở đầu và cuối cho tên riêng của bạn
    __nooooooodontdoit__ = 0

    # 1 dòng trống giữa các định nghĩa trong lớp
    def foo_method(self, x, y=None):
        """Tên phương thức và hàm là ký tự viết thường : lower_case_with_underscores.
        Always use self as first arg.
        """
        pass

    def bar(cls):
        pass

"""
Các tên quy ước đặt tên phổ biến:
snake_case
MACRO_CASE
camelCase
CapWords
"""

# Dòng mới ở cuối tệp

# %% [markdown]
# VD về một đoạn code đẹp

# %%
import math


def add_number_v1():# không được Thừa ký tự space ở trước dấu :
    # add number version 1
    pass


def add_number_v2():
    # add number version 2
    pass


def is_prime_optimal(number):
    if number in [2, 3, 5]:
        return True
    if number % 2 == 0 or number % 3 == 0 or number % 5 == 0 or number < 2:
        return False
    if number < 49:
        return True
    # Chúng ta sẽ phải xử lý xuống dòng thật khéo léo để xóa bỏ phần warning
    if (number % 7) == 0 or (number % 11) == 0 or (number % 13) == 0 or \
        (number % 17) == 0 or (number % 19) == 0 or (number % 23) == 0 or \
        (number % 29) == 0 or (number % 31) == 0 or (number % 37) == 0 or \
            (number % 41) == 0 or (number % 43) == 0 or (number % 47) == 0:  # note
        return False
    if number < 2809:
        return True

    max_range = int(math.sqrt(number)) + 1
    for value in range(53, max_range, 2):  # khoảng trắng xung quanh dấu phẩy bên trái thì không , phải thì có
        if number % value == 0:
            return False
    return True


class SubNumber:

    def check_number_v1(self):
        # sub number version 1
        pass

    def check_number_v2(self):  #Các function trong một class được bao xung quanh bởi 01 dòng trắng
        pass
# Dòng cuối cùng của một file sẽ là 01 dòng trắng.
